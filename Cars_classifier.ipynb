# %%
import azureml.core
azureml.core.VERSION
# Out:
# '1.0.85'

# %%
import os
import shutil

from azureml.core.workspace import Workspace
from azureml.core import Experiment

from azureml.core.compute import ComputeTarget, AmlCompute
from azureml.core.compute_target import ComputeTargetException
from azureml.train.dnn import PyTorch

# %%
ws = Workspace.get(name="Azure_projects", subscription_id='d74ca76c-0758-4302-8894-12939776ca14', resource_group='fastai-practise')

# %%
project_folder ='./cars-classifier'
os.makedirs(project_folder, exist_ok=True)

experiment_name = 'cars-classifier'
experiment=Experiment(ws,name=experiment_name)

# %%
shutil.copy('train.py', project_folder)
# Out:
# './cars-classifier/train.py'

# %%
cluster_name="gpucluster"

try:
    compute_target = ComputeTarget(workspace=ws, name=cluster_name)
    print("Found existing compute target")
    
except ComputeTargetException:
    print('Creating a new compute target...')
    compute_config = AmlCompute.provisioning_configuration(vm_size='STANDARD_NC6',
                                                           max_nodes=4)
    
    compute_target = ComputeTarget.create(ws, cluster_name, compute_config)
    compute_target.wait_for_completion(show_output=True, min_node_count=None, timeout_in_minutes=20)
# Out:
# Creating a new compute target...
# Creating
# Succeeded
# AmlCompute wait for completion finished
#
# Minimum number of nodes requested have been provisioned

# %%
estimator = PyTorch(source_directory=project_folder, 
              compute_target=compute_target, 
              entry_script = 'train.py', 
              use_gpu = True,                   
              pip_packages = ['fastai==1.0.60','pillow==5.4.1'])
# Out:
# WARNING - framework_version is not specified, defaulting to version 1.3.

# %%
run = experiment.submit(estimator)
run.wait_for_completion(show_output=True)
# Out:
# RunId: cars-classifier_1583698130_be5c8985
# Web View: https://ml.azure.com/experiments/cars-classifier/runs/cars-classifier_1583698130_be5c8985?wsid=/subscriptions/d74ca76c-0758-4302-8894-12939776ca14/resourcegroups/fastai-practise/workspaces/Azure_projects
#
# Streaming azureml-logs/20_image_build_log.txt
# =============================================
#
# 2020/03/08 20:09:09 Downloading source code...
# 2020/03/08 20:09:10 Finished downloading source code
# 2020/03/08 20:09:11 Creating Docker network: acb_default_network, driver: 'bridge'
# 2020/03/08 20:09:11 Successfully set up Docker network: acb_default_network
# 2020/03/08 20:09:11 Setting up Docker configuration...
# 2020/03/08 20:09:12 Successfully set up Docker configuration
# 2020/03/08 20:09:12 Logging in to registry: azureprojcrimi6hhqi4cj62.azurecr.io
# 2020/03/08 20:09:13 Successfully logged into azureprojcrimi6hhqi4cj62.azurecr.io
# 2020/03/08 20:09:13 Executing step ID: acb_step_0. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2020/03/08 20:09:13 Scanning for dependencies...
# 2020/03/08 20:09:13 Successfully scanned dependencies
# 2020/03/08 20:09:13 Launching container with name: acb_step_0
# Sending build context to Docker daemon  60.93kB
#
# Step 1/14 : FROM mcr.microsoft.com/azureml/base-gpu:openmpi3.1.2-cuda10.1-cudnn7-ubuntu18.04@sha256:2f1cec174e03a0fe1ed23d5bfa5dca27388361fc7d8205d2dfe55ff46c1a3ed6
# sha256:2f1cec174e03a0fe1ed23d5bfa5dca27388361fc7d8205d2dfe55ff46c1a3ed6: Pulling from azureml/base-gpu
# 7ddbc47eeb70: Pulling fs layer
# c1bbdc448b72: Pulling fs layer
# 8c3b70e39044: Pulling fs layer
# 45d437916d57: Pulling fs layer
# d8f1569ddae6: Pulling fs layer
# 85386706b020: Pulling fs layer
# ee9b457b77d0: Pulling fs layer
# be4f3343ecd3: Pulling fs layer
# 30b4effda4fd: Pulling fs layer
# b398e882f414: Pulling fs layer
# f2e1f2321196: Pulling fs layer
# 1e87b0a17e1a: Pulling fs layer
# e446a9769f53: Pulling fs layer
# 4493432064f7: Pulling fs layer
# 6aadf6f91a8d: Pulling fs layer
# 66d0708eeaf3: Pulling fs layer
# 5952336ab5bb: Pulling fs layer
# b398e882f414: Waiting
# 45d437916d57: Waiting
# d8f1569ddae6: Waiting
# 85386706b020: Waiting
# ee9b457b77d0: Waiting
# be4f3343ecd3: Waiting
# 30b4effda4fd: Waiting
# 1e87b0a17e1a: Waiting
# e446a9769f53: Waiting
# 4493432064f7: Waiting
# 6aadf6f91a8d: Waiting
# 66d0708eeaf3: Waiting
# 5952336ab5bb: Waiting
# f2e1f2321196: Waiting
# 8c3b70e39044: Verifying Checksum
# 8c3b70e39044: Download complete
# c1bbdc448b72: Verifying Checksum
# c1bbdc448b72: Download complete
# 45d437916d57: Verifying Checksum
# 45d437916d57: Download complete
# d8f1569ddae6: Verifying Checksum
# d8f1569ddae6: Download complete
# 85386706b020: Verifying Checksum
# 85386706b020: Download complete
# ee9b457b77d0: Verifying Checksum
# ee9b457b77d0: Download complete
# 7ddbc47eeb70: Verifying Checksum
# 7ddbc47eeb70: Download complete
# 7ddbc47eeb70: Pull complete
# c1bbdc448b72: Pull complete
# 8c3b70e39044: Pull complete
# 45d437916d57: Pull complete
# d8f1569ddae6: Pull complete
# 85386706b020: Pull complete
# ee9b457b77d0: Pull complete
#
# b398e882f414: Verifying Checksum
# b398e882f414: Download complete
# 30b4effda4fd: Verifying Checksum
# 30b4effda4fd: Download complete
# f2e1f2321196: Verifying Checksum
# f2e1f2321196: Download complete
# e446a9769f53: Verifying Checksum
# e446a9769f53: Download complete
# be4f3343ecd3: Verifying Checksum
# be4f3343ecd3: Download complete
# 4493432064f7: Verifying Checksum
# 4493432064f7: Download complete
# 6aadf6f91a8d: Verifying Checksum
# 6aadf6f91a8d: Download complete
# 5952336ab5bb: Verifying Checksum
# 5952336ab5bb: Download complete
# 66d0708eeaf3: Verifying Checksum
# 66d0708eeaf3: Download complete
# 1e87b0a17e1a: Verifying Checksum
# 1e87b0a17e1a: Download complete
#
# be4f3343ecd3: Pull complete
#
# 30b4effda4fd: Pull complete
# b398e882f414: Pull complete
# f2e1f2321196: Pull complete
# 1e87b0a17e1a: Pull complete
# e446a9769f53: Pull complete
# 4493432064f7: Pull complete
# 6aadf6f91a8d: Pull complete
# 66d0708eeaf3: Pull complete
# 5952336ab5bb: Pull complete
# Digest: sha256:2f1cec174e03a0fe1ed23d5bfa5dca27388361fc7d8205d2dfe55ff46c1a3ed6
# Status: Downloaded newer image for mcr.microsoft.com/azureml/base-gpu:openmpi3.1.2-cuda10.1-cudnn7-ubuntu18.04@sha256:2f1cec174e03a0fe1ed23d5bfa5dca27388361fc7d8205d2dfe55ff46c1a3ed6
#  ---> 1aa5c5368838
# Step 2/14 : USER root
#  ---> Running in 54721d93e3da
# Removing intermediate container 54721d93e3da
#  ---> 26bb87642a0a
# Step 3/14 : RUN mkdir -p $HOME/.cache
#  ---> Running in fb160ff7eddf
# Removing intermediate container fb160ff7eddf
#  ---> 9cde14b4c677
# Step 4/14 : WORKDIR /
#  ---> Running in 3e73379903a6
# Removing intermediate container 3e73379903a6
#  ---> 5e2c68bd8d55
# Step 5/14 : COPY azureml-environment-setup/99brokenproxy /etc/apt/apt.conf.d/
#  ---> c08c15a5967b
# Step 6/14 : RUN if dpkg --compare-versions `conda --version | grep -oE '[^ ]+$'` lt 4.4.11; then conda install conda==4.4.11; fi
#  ---> Running in ba0c5e70a94d
# Removing intermediate container ba0c5e70a94d
#  ---> 92b6cc96235b
# Step 7/14 : COPY azureml-environment-setup/mutated_conda_dependencies.yml azureml-environment-setup/mutated_conda_dependencies.yml
#  ---> cf641a14e849
# Step 8/14 : RUN ldconfig /usr/local/cuda/lib64/stubs && conda env create -p /azureml-envs/azureml_92ac115cb67a69781c05c4b3d7de31a4 -f azureml-environment-setup/mutated_conda_dependencies.yml && rm -rf "$HOME/.cache/pip" && conda clean -aqy && CONDA_ROOT_DIR=$(conda info --root) && rm -rf "$CONDA_ROOT_DIR/pkgs" && find "$CONDA_ROOT_DIR" -type d -name __pycache__ -exec rm -rf {} + && ldconfig
#  ---> Running in 5576423108dd
# Solving environment: ...working...
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.5.11
#   latest version: 4.8.2
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# python-3.6.2         | 19.0 MB   |            |   0%
# python-3.6.2         | 19.0 MB   | 7          |   8%
# python-3.6.2         | 19.0 MB   | ##4        |  24%
# python-3.6.2         | 19.0 MB   | ######2    |  62%
# python-3.6.2         | 19.0 MB   | #######8   |  78%
# python-3.6.2         | 19.0 MB   | ########9  |  90%
# python-3.6.2         | 19.0 MB   | #########8 |  98%
# python-3.6.2         | 19.0 MB   | ########## | 100%
#
# wheel-0.34.2         | 24 KB     |            |   0%
# wheel-0.34.2         | 24 KB     | ########## | 100%
#
# zlib-1.2.11          | 105 KB    |            |   0%
# zlib-1.2.11          | 105 KB    | ########## | 100%
#
# ca-certificates-2019 | 145 KB    |            |   0%
# ca-certificates-2019 | 145 KB    | ########## | 100%
#
# libgomp-9.2.0        | 816 KB    |            |   0%
# libgomp-9.2.0        | 816 KB    | #########3 |  93%
# libgomp-9.2.0        | 816 KB    | ########## | 100%
#
# python_abi-3.6       | 4 KB      |            |   0%
# python_abi-3.6       | 4 KB      | ########## | 100%
#
# ncurses-5.9          | 1.1 MB    |            |   0%
# ncurses-5.9          | 1.1 MB    | #######8   |  79%
# ncurses-5.9          | 1.1 MB    | ########7  |  88%
# ncurses-5.9          | 1.1 MB    | #########7 |  97%
# ncurses-5.9          | 1.1 MB    | ########## | 100%
#
# readline-6.2         | 713 KB    |            |   0%
# readline-6.2         | 713 KB    | ########1  |  81%
# readline-6.2         | 713 KB    | ########## | 100%
#
# tk-8.5.19            | 1.9 MB    |            |   0%
# tk-8.5.19            | 1.9 MB    | #######7   |  78%
# tk-8.5.19            | 1.9 MB    | #########  |  90%
# tk-8.5.19            | 1.9 MB    | ########## | 100%
#
# sqlite-3.13.0        | 4.9 MB    |            |   0%
# sqlite-3.13.0        | 4.9 MB    | ###6       |  36%
# sqlite-3.13.0        | 4.9 MB    | #######6   |  77%
# sqlite-3.13.0        | 4.9 MB    | #########5 |  95%
# sqlite-3.13.0        | 4.9 MB    | ########## | 100%
#
# _openmp_mutex-4.5    | 435 KB    |            |   0%
# _openmp_mutex-4.5    | 435 KB    | ########## | 100%
#
# setuptools-45.3.0    | 640 KB    |            |   0%
# setuptools-45.3.0    | 640 KB    | ########4  |  85%
# setuptools-45.3.0    | 640 KB    | ########## | 100%
#
# certifi-2019.11.28   | 149 KB    |            |   0%
# certifi-2019.11.28   | 149 KB    | ########## | 100%
#
# _libgcc_mutex-0.1    | 3 KB      |            |   0%
# _libgcc_mutex-0.1    | 3 KB      | ########## | 100%
#
# xz-5.2.4             | 366 KB    |            |   0%
# xz-5.2.4             | 366 KB    | #########4 |  95%
# xz-5.2.4             | 366 KB    | ########## | 100%
#
# openssl-1.0.2u       | 3.2 MB    |            |   0%
# openssl-1.0.2u       | 3.2 MB    | #######6   |  76%
# openssl-1.0.2u       | 3.2 MB    | #########1 |  91%
# openssl-1.0.2u       | 3.2 MB    | ########## | 100%
# libgcc-ng-9.2.0      | 8.2 MB    |            |   0%
# libgcc-ng-9.2.0      | 8.2 MB    | #####2     |  52%
# libgcc-ng-9.2.0      | 8.2 MB    | #######6   |  77%
# libgcc-ng-9.2.0      | 8.2 MB    | #########5 |  95%
# libgcc-ng-9.2.0      | 8.2 MB    | ########## | 100%
#
# pip-20.0.2           | 1.0 MB    |            |   0%
# pip-20.0.2           | 1.0 MB    | #######9   |  80%
# pip-20.0.2           | 1.0 MB    | #########6 |  96%
# pip-20.0.2           | 1.0 MB    | ########## | 100%
# Downloading and Extracting Packages
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working...
# done
# Collecting fastai==1.0.60
#   Downloading fastai-1.0.60-py3-none-any.whl (237 kB)
# Collecting pillow==5.4.1
#   Downloading Pillow-5.4.1-cp36-cp36m-manylinux1_x86_64.whl (2.0 MB)
# Collecting azureml-defaults
#   Downloading azureml_defaults-1.0.85.1-py2.py3-none-any.whl (3.0 kB)
# Collecting torch==1.3.1
#   Downloading torch-1.3.1-cp36-cp36m-manylinux1_x86_64.whl (734.6 MB)
#
# Collecting torchvision==0.4.1
#   Downloading torchvision-0.4.1-cp36-cp36m-manylinux1_x86_64.whl (10.1 MB)
# Collecting horovod==0.18.1
#   Downloading horovod-0.18.1.tar.gz (2.8 MB)
# Collecting tensorboard==1.14.0
#   Downloading tensorboard-1.14.0-py3-none-any.whl (3.1 MB)
# Collecting future==0.17.1
#   Downloading future-0.17.1.tar.gz (829 kB)
# Collecting scipy
#   Downloading scipy-1.4.1-cp36-cp36m-manylinux1_x86_64.whl (26.1 MB)
# Collecting packaging
#   Downloading packaging-20.3-py2.py3-none-any.whl (37 kB)
# Collecting matplotlib
#   Downloading matplotlib-3.2.0-cp36-cp36m-manylinux1_x86_64.whl (12.4 MB)
# Collecting numexpr
#   Downloading numexpr-2.7.1-cp36-cp36m-manylinux1_x86_64.whl (162 kB)
# Collecting pyyaml
#   Downloading PyYAML-5.3.tar.gz (268 kB)
# Collecting numpy>=1.15
#   Downloading numpy-1.18.1-cp36-cp36m-manylinux1_x86_64.whl (20.1 MB)
# Collecting nvidia-ml-py3
#   Downloading nvidia-ml-py3-7.352.0.tar.gz (19 kB)
# Collecting beautifulsoup4
#   Downloading beautifulsoup4-4.8.2-py3-none-any.whl (106 kB)
# Collecting dataclasses; python_version < "3.7"
#   Downloading dataclasses-0.7-py3-none-any.whl (18 kB)
# Collecting fastprogress>=0.2.1
#   Downloading fastprogress-0.2.2-py3-none-any.whl (12 kB)
# Collecting spacy>=2.0.18
#   Downloading spacy-2.2.3-cp36-cp36m-manylinux1_x86_64.whl (10.4 MB)
# Collecting requests
#   Downloading requests-2.23.0-py2.py3-none-any.whl (58 kB)
# Collecting bottleneck
#   Downloading Bottleneck-1.3.2.tar.gz (88 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
# Collecting pandas
#   Downloading pandas-1.0.1-cp36-cp36m-manylinux1_x86_64.whl (10.1 MB)
# Collecting json-logging-py==0.2
#   Downloading json-logging-py-0.2.tar.gz (3.6 kB)
# Collecting werkzeug==0.16.1
#   Downloading Werkzeug-0.16.1-py2.py3-none-any.whl (327 kB)
# Collecting gunicorn==19.9.0
#   Downloading gunicorn-19.9.0-py2.py3-none-any.whl (112 kB)
# Collecting applicationinsights>=0.11.7
#   Downloading applicationinsights-0.11.9-py2.py3-none-any.whl (58 kB)
# Collecting azureml-core==1.0.85.*
#   Downloading azureml_core-1.0.85.5-py2.py3-none-any.whl (1.2 MB)
# Collecting azureml-model-management-sdk==1.0.1b6.post1
#   Downloading azureml_model_management_sdk-1.0.1b6.post1-py2.py3-none-any.whl (130 kB)
# Collecting configparser==3.7.4
#   Downloading configparser-3.7.4-py2.py3-none-any.whl (22 kB)
# Collecting flask==1.0.3
#   Downloading Flask-1.0.3-py2.py3-none-any.whl (92 kB)
# Collecting six
#   Downloading six-1.14.0-py2.py3-none-any.whl (10 kB)
# Collecting cloudpickle
#   Downloading cloudpickle-1.3.0-py2.py3-none-any.whl (26 kB)
# Collecting psutil
#   Downloading psutil-5.7.0.tar.gz (449 kB)
# Collecting cffi>=1.4.0
#   Downloading cffi-1.14.0-cp36-cp36m-manylinux1_x86_64.whl (399 kB)
# Requirement already satisfied: setuptools>=41.0.0 in /azureml-envs/azureml_92ac115cb67a69781c05c4b3d7de31a4/lib/python3.6/site-packages (from tensorboard==1.14.0->-r /azureml-environment-setup/condaenv.yrgqa_rw.requirements.txt (line 7)) (45.3.0.post20200307)
# Collecting markdown>=2.6.8
#   Downloading Markdown-3.2.1-py2.py3-none-any.whl (88 kB)
# Collecting absl-py>=0.4
#   Downloading absl-py-0.9.0.tar.gz (104 kB)
# Collecting protobuf>=3.6.0
#   Downloading protobuf-3.11.3-cp36-cp36m-manylinux1_x86_64.whl (1.3 MB)
# Requirement already satisfied: wheel>=0.26; python_version >= "3" in /azureml-envs/azureml_92ac115cb67a69781c05c4b3d7de31a4/lib/python3.6/site-packages (from tensorboard==1.14.0->-r /azureml-environment-setup/condaenv.yrgqa_rw.requirements.txt (line 7)) (0.34.2)
# Collecting grpcio>=1.6.3
#   Downloading grpcio-1.27.2-cp36-cp36m-manylinux2010_x86_64.whl (2.7 MB)
# Collecting pyparsing>=2.0.2
#   Downloading pyparsing-2.4.6-py2.py3-none-any.whl (67 kB)
# Collecting python-dateutil>=2.1
#   Downloading python_dateutil-2.8.1-py2.py3-none-any.whl (227 kB)
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.1.0-cp36-cp36m-manylinux1_x86_64.whl (90 kB)
# Collecting cycler>=0.10
#   Downloading cycler-0.10.0-py2.py3-none-any.whl (6.5 kB)
# Collecting soupsieve>=1.2
#   Downloading soupsieve-2.0-py2.py3-none-any.whl (32 kB)
# Collecting srsly<1.1.0,>=0.1.0
#   Downloading srsly-1.0.2-cp36-cp36m-manylinux1_x86_64.whl (185 kB)
# Collecting preshed<3.1.0,>=3.0.2
#   Downloading preshed-3.0.2-cp36-cp36m-manylinux1_x86_64.whl (119 kB)
# Collecting catalogue<1.1.0,>=0.0.7
#   Downloading catalogue-1.0.0-py2.py3-none-any.whl (7.7 kB)
# Collecting blis<0.5.0,>=0.4.0
#   Downloading blis-0.4.1-cp36-cp36m-manylinux1_x86_64.whl (3.7 MB)
# Collecting wasabi<1.1.0,>=0.4.0
#   Downloading wasabi-0.6.0-py3-none-any.whl (20 kB)
# Collecting plac<1.2.0,>=0.9.6
#   Downloading plac-1.1.3-py2.py3-none-any.whl (20 kB)
# Collecting thinc<7.4.0,>=7.3.0
#   Downloading thinc-7.3.1-cp36-cp36m-manylinux1_x86_64.whl (2.2 MB)
# Collecting murmurhash<1.1.0,>=0.28.0
#   Downloading murmurhash-1.0.2-cp36-cp36m-manylinux1_x86_64.whl (19 kB)
# Collecting cymem<2.1.0,>=2.0.2
#   Downloading cymem-2.0.3-cp36-cp36m-manylinux1_x86_64.whl (32 kB)
# Collecting idna<3,>=2.5
#   Downloading idna-2.9-py2.py3-none-any.whl (58 kB)
# Collecting chardet<4,>=3.0.2
#   Downloading chardet-3.0.4-py2.py3-none-any.whl (133 kB)
# Requirement already satisfied: certifi>=2017.4.17 in /azureml-envs/azureml_92ac115cb67a69781c05c4b3d7de31a4/lib/python3.6/site-packages (from requests->fastai==1.0.60->-r /azureml-environment-setup/condaenv.yrgqa_rw.requirements.txt (line 1)) (2019.11.28)
# Collecting urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1
#   Downloading urllib3-1.25.8-py2.py3-none-any.whl (125 kB)
# Collecting pytz>=2017.2
#   Downloading pytz-2019.3-py2.py3-none-any.whl (509 kB)
# Collecting azure-mgmt-storage>=1.5.0
#   Downloading azure_mgmt_storage-8.0.0-py2.py3-none-any.whl (524 kB)
# Collecting docker
#   Downloading docker-4.2.0-py2.py3-none-any.whl (143 kB)
# Collecting ruamel.yaml<=0.15.89,>=0.15.35
#   Downloading ruamel.yaml-0.15.89-cp36-cp36m-manylinux1_x86_64.whl (651 kB)
# Collecting adal>=1.2.0
#   Downloading adal-1.2.2-py2.py3-none-any.whl (53 kB)
# Collecting backports.tempfile
#   Downloading backports.tempfile-1.0-py2.py3-none-any.whl (4.4 kB)
# Collecting msrest>=0.5.1
#   Downloading msrest-0.6.11-py2.py3-none-any.whl (83 kB)
# Collecting cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*
#   Downloading cryptography-2.8-cp34-abi3-manylinux2010_x86_64.whl (2.3 MB)
# Collecting PyJWT
#   Downloading PyJWT-1.7.1-py2.py3-none-any.whl (18 kB)
# Collecting azure-mgmt-authorization>=0.40.0
#   Downloading azure_mgmt_authorization-0.60.0-py2.py3-none-any.whl (82 kB)
# Collecting jsonpickle
#   Downloading jsonpickle-1.3-py2.py3-none-any.whl (32 kB)
# Collecting SecretStorage
#   Downloading SecretStorage-3.1.2-py3-none-any.whl (14 kB)
# Collecting azure-mgmt-containerregistry>=2.0.0
#   Downloading azure_mgmt_containerregistry-2.8.0-py2.py3-none-any.whl (718 kB)
# Collecting azure-mgmt-resource>=1.2.1
#   Downloading azure_mgmt_resource-8.0.1-py2.py3-none-any.whl (758 kB)
# Collecting pyopenssl
#   Downloading pyOpenSSL-19.1.0-py2.py3-none-any.whl (53 kB)
# Collecting pathspec
#   Downloading pathspec-0.7.0-py2.py3-none-any.whl (25 kB)
# Collecting azure-mgmt-keyvault>=0.40.0
#   Downloading azure_mgmt_keyvault-2.1.1-py2.py3-none-any.whl (117 kB)
# Collecting ndg-httpsclient
#   Downloading ndg_httpsclient-0.5.1-py3-none-any.whl (34 kB)
# Collecting jmespath
#   Downloading jmespath-0.9.5-py2.py3-none-any.whl (24 kB)
# Collecting contextlib2
#   Downloading contextlib2-0.6.0.post1-py2.py3-none-any.whl (9.8 kB)
# Collecting azure-graphrbac>=0.40.0
#   Downloading azure_graphrbac-0.61.1-py2.py3-none-any.whl (141 kB)
# Collecting msrestazure>=0.4.33
#   Downloading msrestazure-0.6.2-py2.py3-none-any.whl (40 kB)
# Collecting azure-common>=1.1.12
#   Downloading azure_common-1.1.24-py2.py3-none-any.whl (12 kB)
# Collecting liac-arff>=2.1.1
#   Downloading liac-arff-2.4.0.tar.gz (15 kB)
# Collecting dill>=0.2.7.1
#   Downloading dill-0.3.1.1.tar.gz (151 kB)
# Collecting Jinja2>=2.10
#   Downloading Jinja2-2.11.1-py2.py3-none-any.whl (126 kB)
# Collecting itsdangerous>=0.24
#   Downloading itsdangerous-1.1.0-py2.py3-none-any.whl (16 kB)
# Collecting click>=5.1
#   Downloading Click-7.0-py2.py3-none-any.whl (81 kB)
# Collecting pycparser
#   Downloading pycparser-2.20-py2.py3-none-any.whl (112 kB)
# Collecting importlib-metadata>=0.20; python_version < "3.8"
#   Downloading importlib_metadata-1.5.0-py2.py3-none-any.whl (30 kB)
# Collecting tqdm<5.0.0,>=4.10.0
#   Downloading tqdm-4.43.0-py2.py3-none-any.whl (59 kB)
# Collecting websocket-client>=0.32.0
#   Downloading websocket_client-0.57.0-py2.py3-none-any.whl (200 kB)
# Collecting backports.weakref
#   Downloading backports.weakref-1.0.post1-py2.py3-none-any.whl (5.2 kB)
# Collecting requests-oauthlib>=0.5.0
#   Downloading requests_oauthlib-1.3.0-py2.py3-none-any.whl (23 kB)
# Collecting isodate>=0.6.0
#   Downloading isodate-0.6.0-py2.py3-none-any.whl (45 kB)
# Collecting jeepney>=0.4.2
#   Downloading jeepney-0.4.3-py3-none-any.whl (21 kB)
# Collecting pyasn1>=0.1.1
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Collecting MarkupSafe>=0.23
#   Downloading MarkupSafe-1.1.1-cp36-cp36m-manylinux1_x86_64.whl (27 kB)
# Collecting zipp>=0.5
#   Downloading zipp-3.1.0-py3-none-any.whl (4.9 kB)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.1.0-py2.py3-none-any.whl (147 kB)
# Building wheels for collected packages: horovod, future, pyyaml, nvidia-ml-py3, bottleneck, json-logging-py, psutil, absl-py, liac-arff, dill
#   Building wheel for horovod (setup.py): started
#   Building wheel for horovod (setup.py): finished with status 'error'
#   ERROR: Command errored out with exit status 1:
#    command: /azureml-envs/azureml_92ac115cb67a69781c05c4b3d7de31a4/bin/python -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-ymud0wwm/horovod/setup.py'"'"'; __file__='"'"'/tmp/pip-install-ymud0wwm/horovod/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d /tmp/pip-wheel-08kmclw8
#        cwd: /tmp/pip-install-ymud0wwm/horovod/
#   Complete output (169 lines):
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build/lib.linux-x86_64-3.6
#   creating build/lib.linux-x86_64-3.6/horovod
#   copying horovod/__init__.py -> build/lib.linux-x86_64-3.6/horovod
#   creating build/lib.linux-x86_64-3.6/horovod/tensorflow
#   copying horovod/tensorflow/compression.py -> build/lib.linux-x86_64-3.6/horovod/tensorflow
#   copying horovod/tensorflow/mpi_ops.py -> build/lib.linux-x86_64-3.6/horovod/tensorflow
#   copying horovod/tensorflow/util.py -> build/lib.linux-x86_64-3.6/horovod/tensorflow
#   copying horovod/tensorflow/__init__.py -> build/lib.linux-x86_64-3.6/horovod/tensorflow
#   creating build/lib.linux-x86_64-3.6/horovod/spark
#   copying horovod/spark/__init__.py -> build/lib.linux-x86_64-3.6/horovod/spark
#   creating build/lib.linux-x86_64-3.6/horovod/mxnet
#   copying horovod/mxnet/mpi_ops.py -> build/lib.linux-x86_64-3.6/horovod/mxnet
#   copying horovod/mxnet/__init__.py -> build/lib.linux-x86_64-3.6/horovod/mxnet
#   creating build/lib.linux-x86_64-3.6/horovod/run
#   copying horovod/run/task_fn.py -> build/lib.linux-x86_64-3.6/horovod/run
#   copying horovod/run/mpi_run.py -> build/lib.linux-x86_64-3.6/horovod/run
#   copying horovod/run/gloo_run.py -> build/lib.linux-x86_64-3.6/horovod/run
#   copying horovod/run/__init__.py -> build/lib.linux-x86_64-3.6/horovod/run
#   copying horovod/run/run.py -> build/lib.linux-x86_64-3.6/horovod/run
#   creating build/lib.linux-x86_64-3.6/horovod/keras
#   copying horovod/keras/__init__.py -> build/lib.linux-x86_64-3.6/horovod/keras
#   copying horovod/keras/callbacks.py -> build/lib.linux-x86_64-3.6/horovod/keras
#   creating build/lib.linux-x86_64-3.6/horovod/_keras
#   copying horovod/_keras/__init__.py -> build/lib.linux-x86_64-3.6/horovod/_keras
#   copying horovod/_keras/callbacks.py -> build/lib.linux-x86_64-3.6/horovod/_keras
#   creating build/lib.linux-x86_64-3.6/horovod/torch
#   copying horovod/torch/compression.py -> build/lib.linux-x86_64-3.6/horovod/torch
#   copying horovod/torch/mpi_ops.py -> build/lib.linux-x86_64-3.6/horovod/torch
#   copying horovod/torch/__init__.py -> build/lib.linux-x86_64-3.6/horovod/torch
#   creating build/lib.linux-x86_64-3.6/horovod/common
#   copying horovod/common/basics.py -> build/lib.linux-x86_64-3.6/horovod/common
#   copying horovod/common/util.py -> build/lib.linux-x86_64-3.6/horovod/common
#   copying horovod/common/__init__.py -> build/lib.linux-x86_64-3.6/horovod/common
#   creating build/lib.linux-x86_64-3.6/horovod/tensorflow/keras
#   copying horovod/tensorflow/keras/__init__.py -> build/lib.linux-x86_64-3.6/horovod/tensorflow/keras
#   copying horovod/tensorflow/keras/callbacks.py -> build/lib.linux-x86_64-3.6/horovod/tensorflow/keras
#   creating build/lib.linux-x86_64-3.6/horovod/spark/task
#   copying horovod/spark/task/mpirun_exec_fn.py -> build/lib.linux-x86_64-3.6/horovod/spark/task
#   copying horovod/spark/task/task_service.py -> build/lib.linux-x86_64-3.6/horovod/spark/task
#   copying horovod/spark/task/__init__.py -> build/lib.linux-x86_64-3.6/horovod/spark/task
#   creating build/lib.linux-x86_64-3.6/horovod/spark/driver
#   copying horovod/spark/driver/mpirun_rsh.py -> build/lib.linux-x86_64-3.6/horovod/spark/driver
#   copying horovod/spark/driver/driver_service.py -> build/lib.linux-x86_64-3.6/horovod/spark/driver
#   copying horovod/spark/driver/__init__.py -> build/lib.linux-x86_64-3.6/horovod/spark/driver
#   copying horovod/spark/driver/job_id.py -> build/lib.linux-x86_64-3.6/horovod/spark/driver
#   creating build/lib.linux-x86_64-3.6/horovod/run/task
#   copying horovod/run/task/task_service.py -> build/lib.linux-x86_64-3.6/horovod/run/task
#   copying horovod/run/task/__init__.py -> build/lib.linux-x86_64-3.6/horovod/run/task
#   creating build/lib.linux-x86_64-3.6/horovod/run/driver
#   copying horovod/run/driver/driver_service.py -> build/lib.linux-x86_64-3.6/horovod/run/driver
#   copying horovod/run/driver/__init__.py -> build/lib.linux-x86_64-3.6/horovod/run/driver
#   creating build/lib.linux-x86_64-3.6/horovod/run/util
#   copying horovod/run/util/threads.py -> build/lib.linux-x86_64-3.6/horovod/run/util
#   copying horovod/run/util/__init__.py -> build/lib.linux-x86_64-3.6/horovod/run/util
#   copying horovod/run/util/network.py -> build/lib.linux-x86_64-3.6/horovod/run/util
#   copying horovod/run/util/cache.py -> build/lib.linux-x86_64-3.6/horovod/run/util
#   creating build/lib.linux-x86_64-3.6/horovod/run/rendezvous
#   copying horovod/run/rendezvous/__init__.py -> build/lib.linux-x86_64-3.6/horovod/run/rendezvous
#   copying horovod/run/rendezvous/http_server.py -> build/lib.linux-x86_64-3.6/horovod/run/rendezvous
#   creating build/lib.linux-x86_64-3.6/horovod/run/common
#   copying horovod/run/common/__init__.py -> build/lib.linux-x86_64-3.6/horovod/run/common
#   creating build/lib.linux-x86_64-3.6/horovod/run/common/util
#   copying horovod/run/common/util/config_parser.py -> build/lib.linux-x86_64-3.6/horovod/run/common/util
#   copying horovod/run/common/util/secret.py -> build/lib.linux-x86_64-3.6/horovod/run/common/util
#   copying horovod/run/common/util/settings.py -> build/lib.linux-x86_64-3.6/horovod/run/common/util
#   copying horovod/run/common/util/safe_shell_exec.py -> build/lib.linux-x86_64-3.6/horovod/run/common/util
#   copying horovod/run/common/util/host_hash.py -> build/lib.linux-x86_64-3.6/horovod/run/common/util
#   copying horovod/run/common/util/codec.py -> build/lib.linux-x86_64-3.6/horovod/run/common/util
#   copying horovod/run/common/util/env.py -> build/lib.linux-x86_64-3.6/horovod/run/common/util
#   copying horovod/run/common/util/__init__.py -> build/lib.linux-x86_64-3.6/horovod/run/common/util
#   copying horovod/run/common/util/timeout.py -> build/lib.linux-x86_64-3.6/horovod/run/common/util
#   copying horovod/run/common/util/network.py -> build/lib.linux-x86_64-3.6/horovod/run/common/util
#   creating build/lib.linux-x86_64-3.6/horovod/run/common/service
#   copying horovod/run/common/service/task_service.py -> build/lib.linux-x86_64-3.6/horovod/run/common/service
#   copying horovod/run/common/service/driver_service.py -> build/lib.linux-x86_64-3.6/horovod/run/common/service
#   copying horovod/run/common/service/__init__.py -> build/lib.linux-x86_64-3.6/horovod/run/common/service
#   creating build/lib.linux-x86_64-3.6/horovod/torch/mpi_lib_impl
#   copying horovod/torch/mpi_lib_impl/__init__.py -> build/lib.linux-x86_64-3.6/horovod/torch/mpi_lib_impl
#   creating build/lib.linux-x86_64-3.6/horovod/torch/mpi_lib
#   copying horovod/torch/mpi_lib/__init__.py -> build/lib.linux-x86_64-3.6/horovod/torch/mpi_lib
#   running build_ext
#   gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -fPIC -std=c++11 -fPIC -O2 -Wall -I/azureml-envs/azureml_92ac115cb67a69781c05c4b3d7de31a4/include/python3.6m -c build/temp.linux-x86_64-3.6/test_compile/test_cpp_flags.cc -o build/temp.linux-x86_64-3.6/test_compile/test_cpp_flags.o
#   cc1plus: warning: command line option â€˜-Wstrict-prototypesâ€™ is valid for C/ObjC but not for C++
#   gcc -pthread -shared -L/azureml-envs/azureml_92ac115cb67a69781c05c4b3d7de31a4/lib -Wl,-rpath=/azureml-envs/azureml_92ac115cb67a69781c05c4b3d7de31a4/lib,--no-as-needed -L/azureml-envs/azureml_92ac115cb67a69781c05c4b3d7de31a4/lib -Wl,-rpath=/azureml-envs/azureml_92ac115cb67a69781c05c4b3d7de31a4/lib,--no-as-needed build/temp.linux-x86_64-3.6/test_compile/test_cpp_flags.o -L/azureml-envs/azureml_92ac115cb67a69781c05c4b3d7de31a4/lib -o build/temp.linux-x86_64-3.6/test_compile/test_cpp_flags.so
#   gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -fPIC -I/azureml-envs/azureml_92ac115cb67a69781c05c4b3d7de31a4/include/python3.6m -c build/temp.linux-x86_64-3.6/test_compile/test_link_flags.cc -o build/temp.linux-x86_64-3.6/test_compile/test_link_flags.o
#   cc1plus: warning: command line option â€˜-Wstrict-prototypesâ€™ is valid for C/ObjC but not for C++
#   gcc -pthread -shared -L/azureml-envs/azureml_92ac115cb67a69781c05c4b3d7de31a4/lib -Wl,-rpath=/azureml-envs/azureml_92ac115cb67a69781c05c4b3d7de31a4/lib,--no-as-needed -L/azureml-envs/azureml_92ac115cb67a69781c05c4b3d7de31a4/lib -Wl,-rpath=/azureml-envs/azureml_92ac115cb67a69781c05c4b3d7de31a4/lib,--no-as-needed -Wl,--version-script=horovod.lds build/temp.linux-x86_64-3.6/test_compile/test_link_flags.o -L/azureml-envs/azureml_92ac115cb67a69781c05c4b3d7de31a4/lib -o build/temp.linux-x86_64-3.6/test_compile/test_link_flags.so
#   INFO: Cannot find CMake, will skip compiling Horovod with Gloo.
#   gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -fPIC -std=c++11 -fPIC -O2 -Wall -I/usr/local/cuda/include -I/azureml-envs/azureml_92ac115cb67a69781c05c4b3d7de31a4/include/python3.6m -c build/temp.linux-x86_64-3.6/test_compile/test_cuda.cc -o build/temp.linux-x86_64-3.6/test_compile/test_cuda.o
#   cc1plus: warning: command line option â€˜-Wstrict-prototypesâ€™ is valid for C/ObjC but not for C++
#   gcc -pthread -shared -L/azureml-envs/azureml_92ac115cb67a69781c05c4b3d7de31a4/lib -Wl,-rpath=/azureml-envs/azureml_92ac115cb67a69781c05c4b3d7de31a4/lib,--no-as-needed -L/azureml-envs/azureml_92ac115cb67a69781c05c4b3d7de31a4/lib -Wl,-rpath=/azureml-envs/azureml_92ac115cb67a69781c05c4b3d7de31a4/lib,--no-as-needed build/temp.linux-x86_64-3.6/test_compile/test_cuda.o -L/usr/local/cuda/lib -L/usr/local/cuda/lib64 -L/azureml-envs/azureml_92ac115cb67a69781c05c4b3d7de31a4/lib -lcudart -o build/temp.linux-x86_64-3.6/test_compile/test_cuda.so
#   gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -fPIC -std=c++11 -fPIC -O2 -Wall -I/usr/local/cuda/include -I/azureml-envs/azureml_92ac115cb67a69781c05c4b3d7de31a4/include/python3.6m -c build/temp.linux-x86_64-3.6/test_compile/test_nccl.cc -o build/temp.linux-x86_64-3.6/test_compile/test_nccl.o
#   cc1plus: warning: command line option â€˜-Wstrict-prototypesâ€™ is valid for C/ObjC but not for C++
#   gcc -pthread -shared -L/azureml-envs/azureml_92ac115cb67a69781c05c4b3d7de31a4/lib -Wl,-rpath=/azureml-envs/azureml_92ac115cb67a69781c05c4b3d7de31a4/lib,--no-as-needed -L/azureml-envs/azureml_92ac115cb67a69781c05c4b3d7de31a4/lib -Wl,-rpath=/azureml-envs/azureml_92ac115cb67a69781c05c4b3d7de31a4/lib,--no-as-needed build/temp.linux-x86_64-3.6/test_compile/test_nccl.o -L/usr/local/cuda/lib -L/usr/local/cuda/lib64 -L/azureml-envs/azureml_92ac115cb67a69781c05c4b3d7de31a4/lib -lnccl_static -o build/temp.linux-x86_64-3.6/test_compile/test_nccl.so
#   INFO: Unable to build TensorFlow plugin, will skip it.
#
#   Traceback (most recent call last):
#     File "/tmp/pip-install-ymud0wwm/horovod/setup.py", line 72, in check_tf_version
#       import tensorflow as tf
#   ModuleNotFoundError: No module named 'tensorflow'
#
#   During handling of the above exception, another exception occurred:
#
#   Traceback (most recent call last):
#     File "/tmp/pip-install-ymud0wwm/horovod/setup.py", line 1375, in build_extensions
#       build_tf_extension(self, options)
#     File "/tmp/pip-install-ymud0wwm/horovod/setup.py", line 851, in build_tf_extension
#       check_tf_version()
#     File "/tmp/pip-install-ymud0wwm/horovod/setup.py", line 79, in check_tf_version
#       'import tensorflow failed, is it installed?\n\n%s' % traceback.format_exc())
#   distutils.errors.DistutilsPlatformError: import tensorflow failed, is it installed?
#
#   Traceback (most recent call last):
#     File "/tmp/pip-install-ymud0wwm/horovod/setup.py", line 72, in check_tf_version
#       import tensorflow as tf
#   ModuleNotFoundError: No module named 'tensorflow'
#
#
#   INFO: Unable to build PyTorch plugin, will skip it.
#
#   Traceback (most recent call last):
#     File "/tmp/pip-install-ymud0wwm/horovod/setup.py", line 1060, in check_torch_version
#       import torch
#   ModuleNotFoundError: No module named 'torch'
#
#   During handling of the above exception, another exception occurred:
#
#   Traceback (most recent call last):
#     File "/tmp/pip-install-ymud0wwm/horovod/setup.py", line 1387, in build_extensions
#       torch_version = check_torch_version()
#     File "/tmp/pip-install-ymud0wwm/horovod/setup.py", line 1067, in check_torch_version
#       'import torch failed, is it installed?\n\n%s' % traceback.format_exc())
#   distutils.errors.DistutilsPlatformError: import torch failed, is it installed?
#
#   Traceback (most recent call last):
#     File "/tmp/pip-install-ymud0wwm/horovod/setup.py", line 1060, in check_torch_version
#       import torch
#   ModuleNotFoundError: No module named 'torch'
#
#
#   INFO: Unable to build MXNet plugin, will skip it.
#
#   Traceback (most recent call last):
#     File "/tmp/pip-install-ymud0wwm/horovod/setup.py", line 88, in check_mx_version
#       import mxnet as mx
#   ModuleNotFoundError: No module named 'mxnet'
#
#   During handling of the above exception, another exception occurred:
#
#   Traceback (most recent call last):
#     File "/tmp/pip-install-ymud0wwm/horovod/setup.py", line 1403, in build_extensions
#       build_mx_extension(self, options)
#     File "/tmp/pip-install-ymud0wwm/horovod/setup.py", line 1000, in build_mx_extension
#       check_mx_version()
#     File "/tmp/pip-install-ymud0wwm/horovod/setup.py", line 95, in check_mx_version
#       'import mxnet failed, is it installed?\n\n%s' % traceback.format_exc())
#   distutils.errors.DistutilsPlatformError: import mxnet failed, is it installed?
#
#   Traceback (most recent call last):
#     File "/tmp/pip-install-ymud0wwm/horovod/setup.py", line 88, in check_mx_version
#       import mxnet as mx
#   ModuleNotFoundError: No module named 'mxnet'
#
#
#   error: None of TensorFlow, PyTorch, or MXNet plugins were built. See errors above.
#   ----------------------------------------
#   ERROR: Failed building wheel for horovod
#   Running setup.py clean for horovod
#   Building wheel for future (setup.py): started
#   Building wheel for future (setup.py): finished with status 'done'
#   Created wheel for future: filename=future-0.17.1-py3-none-any.whl size=488732 sha256=155f92e7ff3fedcd363c57fecc49dd8ba1fa071b0222d21d382c4d1b3e193744
#   Stored in directory: /root/.cache/pip/wheels/c4/f0/e2/8e4ecc9e1b12a428a7657ba683576d3e79d0a75982f63e8fd2
#   Building wheel for pyyaml (setup.py): started
#   Building wheel for pyyaml (setup.py): finished with status 'done'
#   Created wheel for pyyaml: filename=PyYAML-5.3-cp36-cp36m-linux_x86_64.whl size=44229 sha256=90f7f2bd37cc8caafdf1aa823e49b7c06c6facceaab0d757936ee10306e543ac
#   Stored in directory: /root/.cache/pip/wheels/b1/86/0d/10e6c39d3a2b85ba807d7657ee80f08cc16c03f2aa2adf8e46
#   Building wheel for nvidia-ml-py3 (setup.py): started
#   Building wheel for nvidia-ml-py3 (setup.py): finished with status 'done'
#   Created wheel for nvidia-ml-py3: filename=nvidia_ml_py3-7.352.0-py3-none-any.whl size=19189 sha256=2d637efe70e125b103d47ddb1788885b960f7a9d9b8ccfb2bd09759c1eb6cd7a
#   Stored in directory: /root/.cache/pip/wheels/7f/26/a3/33f2079871e2bebb3f53a2b21c3ec64129b8efdd18a6263a52
#   Building wheel for bottleneck (PEP 517): started
#   Building wheel for bottleneck (PEP 517): finished with status 'done'
#   Created wheel for bottleneck: filename=Bottleneck-1.3.2-cp36-cp36m-linux_x86_64.whl size=331553 sha256=9ab1b5aa991b173c29c9599f15550b603b85e81f878fe6eabdff58550cdd803e
#   Stored in directory: /root/.cache/pip/wheels/f7/a7/14/9be836efed01ac0eb3c125ac006c143b55ebf689269877d0e8
#   Building wheel for json-logging-py (setup.py): started
#   Building wheel for json-logging-py (setup.py): finished with status 'done'
#   Created wheel for json-logging-py: filename=json_logging_py-0.2-py3-none-any.whl size=3923 sha256=412e8472c13e7083d7cd20dfe06e9cd2265e9a43e1cc85e9cfd94e5ad311b7a3
#   Stored in directory: /root/.cache/pip/wheels/e2/1d/52/535a274b9c2ce7d4064838f2bdb62013801281ef7d7f21e2ee
#   Building wheel for psutil (setup.py): started
#   Building wheel for psutil (setup.py): finished with status 'done'
#   Created wheel for psutil: filename=psutil-5.7.0-cp36-cp36m-linux_x86_64.whl size=272952 sha256=9584892a47d796c2f18f45d0bf69b2c4349e4ec632a838fcecf66a9e729f18de
#   Stored in directory: /root/.cache/pip/wheels/a1/d9/f2/b5620c01e9b3e858c6877b1045fda5b115cf7df6490f883382
#   Building wheel for absl-py (setup.py): started
#   Building wheel for absl-py (setup.py): finished with status 'done'
#   Created wheel for absl-py: filename=absl_py-0.9.0-py3-none-any.whl size=121931 sha256=5732362eeb7555a2b4c2abc044f44bd07e390b6ef85a11bfeaa1f66993ecab99
#   Stored in directory: /root/.cache/pip/wheels/c3/af/84/3962a6af7b4ab336e951b7877dcfb758cf94548bb1771e0679
#   Building wheel for liac-arff (setup.py): started
#   Building wheel for liac-arff (setup.py): finished with status 'done'
#   Created wheel for liac-arff: filename=liac_arff-2.4.0-py3-none-any.whl size=13333 sha256=9c74cddc0f3f64d20616105085baf7170aa0d23db3e4fbe745ed82088eb58d7d
#   Stored in directory: /root/.cache/pip/wheels/ba/2a/e1/6f7be2e2ea150e2486bff64fd6f0670f4f35f4c8f31c819fb8
#   Building wheel for dill (setup.py): started
#   Building wheel for dill (setup.py): finished with status 'done'
#   Created wheel for dill: filename=dill-0.3.1.1-py3-none-any.whl size=78530 sha256=486525d2565fefc09c71c96598705ceabd1c041573b6e8fc3ca1347799f691ea
#   Stored in directory: /root/.cache/pip/wheels/09/84/74/d2b4feb9ac9488bc83c475cb2cbe8e8b7d9cea8320d32f3787
# Successfully built future pyyaml nvidia-ml-py3 bottleneck json-logging-py psutil absl-py liac-arff dill
# Failed to build horovod
# ERROR: torchvision 0.4.1 has requirement torch==1.3.0, but you'll have torch 1.3.1 which is incompatible.
# Installing collected packages: six, numpy, torch, pillow, torchvision, scipy, pyparsing, packaging, python-dateutil, kiwisolver, cycler, matplotlib, numexpr, pyyaml, nvidia-ml-py3, soupsieve, beautifulsoup4, dataclasses, fastprogress, srsly, murmurhash, cymem, preshed, zipp, importlib-metadata, catalogue, blis, wasabi, plac, tqdm, thinc, idna, chardet, urllib3, requests, spacy, bottleneck, pytz, pandas, fastai, json-logging-py, werkzeug, gunicorn, applicationinsights, oauthlib, requests-oauthlib, isodate, msrest, azure-common, pycparser, cffi, cryptography, PyJWT, adal, msrestazure, azure-mgmt-storage, websocket-client, docker, ruamel.yaml, backports.weakref, backports.tempfile, azure-mgmt-authorization, jsonpickle, jeepney, SecretStorage, azure-mgmt-containerregistry, azure-mgmt-resource, pyopenssl, pathspec, azure-mgmt-keyvault, pyasn1, ndg-httpsclient, jmespath, contextlib2, azure-graphrbac, azureml-core, liac-arff, dill, azureml-model-management-sdk, configparser, MarkupSafe, Jinja2, itsdangerous, click, flask, azureml-defaults, cloudpickle, psutil, horovod, markdown, absl-py, protobuf, grpcio, tensorboard, future
#
#     Running setup.py install for horovod: started
#     Running setup.py install for horovod: still running...
#     Running setup.py install for horovod: finished with status 'done'
# Successfully installed Jinja2-2.11.1 MarkupSafe-1.1.1 PyJWT-1.7.1 SecretStorage-3.1.2 absl-py-0.9.0 adal-1.2.2 applicationinsights-0.11.9 azure-common-1.1.24 azure-graphrbac-0.61.1 azure-mgmt-authorization-0.60.0 azure-mgmt-containerregistry-2.8.0 azure-mgmt-keyvault-2.1.1 azure-mgmt-resource-8.0.1 azure-mgmt-storage-8.0.0 azureml-core-1.0.85.5 azureml-defaults-1.0.85.1 azureml-model-management-sdk-1.0.1b6.post1 backports.tempfile-1.0 backports.weakref-1.0.post1 beautifulsoup4-4.8.2 blis-0.4.1 bottleneck-1.3.2 catalogue-1.0.0 cffi-1.14.0 chardet-3.0.4 click-7.0 cloudpickle-1.3.0 configparser-3.7.4 contextlib2-0.6.0.post1 cryptography-2.8 cycler-0.10.0 cymem-2.0.3 dataclasses-0.7 dill-0.3.1.1 docker-4.2.0 fastai-1.0.60 fastprogress-0.2.2 flask-1.0.3 future-0.17.1 grpcio-1.27.2 gunicorn-19.9.0 horovod-0.18.1 idna-2.9 importlib-metadata-1.5.0 isodate-0.6.0 itsdangerous-1.1.0 jeepney-0.4.3 jmespath-0.9.5 json-logging-py-0.2 jsonpickle-1.3 kiwisolver-1.1.0 liac-arff-2.4.0 markdown-3.2.1 matplotlib-3.2.0 msrest-0.6.11 msrestazure-0.6.2 murmurhash-1.0.2 ndg-httpsclient-0.5.1 numexpr-2.7.1 numpy-1.18.1 nvidia-ml-py3-7.352.0 oauthlib-3.1.0 packaging-20.3 pandas-1.0.1 pathspec-0.7.0 pillow-5.4.1 plac-1.1.3 preshed-3.0.2 protobuf-3.11.3 psutil-5.7.0 pyasn1-0.4.8 pycparser-2.20 pyopenssl-19.1.0 pyparsing-2.4.6 python-dateutil-2.8.1 pytz-2019.3 pyyaml-5.3 requests-2.23.0 requests-oauthlib-1.3.0 ruamel.yaml-0.15.89 scipy-1.4.1 six-1.14.0 soupsieve-2.0 spacy-2.2.3 srsly-1.0.2 tensorboard-1.14.0 thinc-7.3.1 torch-1.3.1 torchvision-0.4.1 tqdm-4.43.0 urllib3-1.25.8 wasabi-0.6.0 websocket-client-0.57.0 werkzeug-0.16.1 zipp-3.1.0
#
# #
# # To activate this environment, use:
# # > source activate /azureml-envs/azureml_92ac115cb67a69781c05c4b3d7de31a4
# #
# # To deactivate an active environment, use:
# # > source deactivate
# #
#
# Removing intermediate container 5576423108dd
#  ---> b501ea9682a5
# Step 9/14 : ENV PATH /azureml-envs/azureml_92ac115cb67a69781c05c4b3d7de31a4/bin:$PATH
#  ---> Running in a7720d001a98
# Removing intermediate container a7720d001a98
#  ---> 8574191b2055
# Step 10/14 : ENV AZUREML_CONDA_ENVIRONMENT_PATH /azureml-envs/azureml_92ac115cb67a69781c05c4b3d7de31a4
#  ---> Running in 29bf1c3b7880
# Removing intermediate container 29bf1c3b7880
#  ---> bf105ac8ec00
# Step 11/14 : ENV LD_LIBRARY_PATH /azureml-envs/azureml_92ac115cb67a69781c05c4b3d7de31a4/lib:$LD_LIBRARY_PATH
#  ---> Running in baff045037bf
# Removing intermediate container baff045037bf
#  ---> 175bdf813b98
# Step 12/14 : COPY azureml-environment-setup/spark_cache.py azureml-environment-setup/log4j.properties /azureml-environment-setup/
#  ---> af69f203a70a
# Step 13/14 : ENV AZUREML_ENVIRONMENT_IMAGE True
#  ---> Running in 22764ce2fc95
# Removing intermediate container 22764ce2fc95
#  ---> a7681a03f166
# Step 14/14 : CMD ["bash"]
#  ---> Running in 162a3b867ecf
# Removing intermediate container 162a3b867ecf
#  ---> 5481fc800f0f
# Successfully built 5481fc800f0f
# Successfully tagged azureprojcrimi6hhqi4cj62.azurecr.io/azureml/azureml_bb7505235b95568dd47cb4e64da6eeda:latest
# 2020/03/08 20:16:41 Successfully executed container: acb_step_0
# 2020/03/08 20:16:41 Executing step ID: acb_step_1. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2020/03/08 20:16:41 Pushing image: azureprojcrimi6hhqi4cj62.azurecr.io/azureml/azureml_bb7505235b95568dd47cb4e64da6eeda:latest, attempt 1
# The push refers to repository [azureprojcrimi6hhqi4cj62.azurecr.io/azureml/azureml_bb7505235b95568dd47cb4e64da6eeda]
# f997b3b711bd: Preparing
# 8a3b3db22e4b: Preparing
# af9de286c734: Preparing
# 0b667249e491: Preparing
# 880373920e86: Preparing
# de0405138ef8: Preparing
# 09f5cc6238d6: Preparing
# 76ce30d10f04: Preparing
# ae1aecc127c3: Preparing
# 0cf1d4dd1413: Preparing
# 0e6f845ffcee: Preparing
# c63d8cf11fb9: Preparing
# a31485cd6e70: Preparing
# 1db09913a256: Preparing
# 2e282f599fd6: Preparing
# e6f174f76be4: Preparing
# 808fd332a58a: Preparing
# b16af11cbf29: Preparing
# 37b9a4b22186: Preparing
# e0b3afb09dc3: Preparing
# 6c01b5a53aac: Preparing
# 2c6ac8e5063e: Preparing
# cc967c529ced: Preparing
# 2e282f599fd6: Waiting
# de0405138ef8: Waiting
# e6f174f76be4: Waiting
# 09f5cc6238d6: Waiting
# 76ce30d10f04: Waiting
# 808fd332a58a: Waiting
# b16af11cbf29: Waiting
# ae1aecc127c3: Waiting
# 37b9a4b22186: Waiting
# 0cf1d4dd1413: Waiting
# e0b3afb09dc3: Waiting
# 6c01b5a53aac: Waiting
# 0e6f845ffcee: Waiting
# 2c6ac8e5063e: Waiting
# cc967c529ced: Waiting
# c63d8cf11fb9: Waiting
# a31485cd6e70: Waiting
# 1db09913a256: Waiting
# 880373920e86: Pushed
# f997b3b711bd: Pushed
# af9de286c734: Pushed
# de0405138ef8: Pushed
# 0b667249e491: Pushed
# 76ce30d10f04: Pushed
# 09f5cc6238d6: Pushed
# ae1aecc127c3: Pushed
# 0e6f845ffcee: Pushed
# c63d8cf11fb9: Pushed
# 0cf1d4dd1413: Pushed
# a31485cd6e70: Pushed
# 808fd332a58a: Pushed
# b16af11cbf29: Pushed
# 37b9a4b22186: Pushed
# e0b3afb09dc3: Pushed
# 6c01b5a53aac: Pushed
# 2c6ac8e5063e: Pushed
# 1db09913a256: Pushed
# cc967c529ced: Pushed
# e6f174f76be4: Pushed
# 2e282f599fd6: Pushed
# 8a3b3db22e4b: Pushed
# latest: digest: sha256:4932fc44edac0025d0c189c51532920fe8f118fafc82af6c1b8394c5e6c18927 size: 5152
# 2020/03/08 20:21:06 Successfully pushed image: azureprojcrimi6hhqi4cj62.azurecr.io/azureml/azureml_bb7505235b95568dd47cb4e64da6eeda:latest
# 2020/03/08 20:21:06 Step ID: acb_step_0 marked as successful (elapsed time in seconds: 448.818742)
# 2020/03/08 20:21:06 Populating digests for step ID: acb_step_0...
# 2020/03/08 20:21:07 Successfully populated digests for step ID: acb_step_0
# 2020/03/08 20:21:07 Step ID: acb_step_1 marked as successful (elapsed time in seconds: 264.338287)
# 2020/03/08 20:21:07 The following dependencies were found:
# 2020/03/08 20:21:07
# - image:
#     registry: azureprojcrimi6hhqi4cj62.azurecr.io
#     repository: azureml/azureml_bb7505235b95568dd47cb4e64da6eeda
#     tag: latest
#     digest: sha256:4932fc44edac0025d0c189c51532920fe8f118fafc82af6c1b8394c5e6c18927
#   runtime-dependency:
#     registry: mcr.microsoft.com
#     repository: azureml/base-gpu
#     tag: openmpi3.1.2-cuda10.1-cudnn7-ubuntu18.04
#     digest: sha256:2f1cec174e03a0fe1ed23d5bfa5dca27388361fc7d8205d2dfe55ff46c1a3ed6
#   git: {}
#
#
# Run ID: cp1 was successful after 12m0s
#
# Streaming azureml-logs/55_azureml-execution-tvmps_11a6bc01d07234d5979ed836b7cc1d1394bea0d5b6cb70800269254b5828b3d0_d.txt
# ========================================================================================================================
#
# 2020-03-08T20:24:37Z Starting output-watcher...
# 2020-03-08T20:24:37Z IsDedicatedCompute == True, won't poll for Low Pri Preemption
# Login Succeeded
# Using default tag: latest
# latest: Pulling from azureml/azureml_bb7505235b95568dd47cb4e64da6eeda
# 7ddbc47eeb70: Pulling fs layer
# c1bbdc448b72: Pulling fs layer
# 8c3b70e39044: Pulling fs layer
# 45d437916d57: Pulling fs layer
# d8f1569ddae6: Pulling fs layer
# 85386706b020: Pulling fs layer
# ee9b457b77d0: Pulling fs layer
# be4f3343ecd3: Pulling fs layer
# 30b4effda4fd: Pulling fs layer
# b398e882f414: Pulling fs layer
# f2e1f2321196: Pulling fs layer
# 1e87b0a17e1a: Pulling fs layer
# e446a9769f53: Pulling fs layer
# 4493432064f7: Pulling fs layer
# 6aadf6f91a8d: Pulling fs layer
# 66d0708eeaf3: Pulling fs layer
# 5952336ab5bb: Pulling fs layer
# 5b8a51d6bfdb: Pulling fs layer
# 1e776d6ab67d: Pulling fs layer
# 423bbe9704b1: Pulling fs layer
# fd9b2161165a: Pulling fs layer
# 052e61da4995: Pulling fs layer
# ee9b457b77d0: Waiting
# 0a28138dee63: Pulling fs layer
# be4f3343ecd3: Waiting
# 30b4effda4fd: Waiting
# 1e87b0a17e1a: Waiting
# b398e882f414: Waiting
# f2e1f2321196: Waiting
# e446a9769f53: Waiting
# 4493432064f7: Waiting
# 6aadf6f91a8d: Waiting
# 45d437916d57: Waiting
# 66d0708eeaf3: Waiting
# fd9b2161165a: Waiting
# 5952336ab5bb: Waiting
# 052e61da4995: Waiting
# 5b8a51d6bfdb: Waiting
# 0a28138dee63: Waiting
# 1e776d6ab67d: Waiting
# d8f1569ddae6: Waiting
# 423bbe9704b1: Waiting
# 85386706b020: Waiting
# c1bbdc448b72: Verifying Checksum
# c1bbdc448b72: Download complete
# 8c3b70e39044: Verifying Checksum
# 8c3b70e39044: Download complete
# 45d437916d57: Verifying Checksum
# 45d437916d57: Download complete
# 7ddbc47eeb70: Verifying Checksum
# 7ddbc47eeb70: Download complete
# d8f1569ddae6: Verifying Checksum
# d8f1569ddae6: Download complete
# ee9b457b77d0: Download complete
# 85386706b020: Verifying Checksum
# 85386706b020: Download complete
# 7ddbc47eeb70: Pull complete
# c1bbdc448b72: Pull complete
# 8c3b70e39044: Pull complete
# 45d437916d57: Pull complete
# d8f1569ddae6: Pull complete
# 85386706b020: Pull complete
# ee9b457b77d0: Pull complete
# b398e882f414: Verifying Checksum
# b398e882f414: Download complete
# be4f3343ecd3: Verifying Checksum
# be4f3343ecd3: Download complete
# f2e1f2321196: Verifying Checksum
# f2e1f2321196: Download complete
# 1e87b0a17e1a: Verifying Checksum
# 1e87b0a17e1a: Download complete
# e446a9769f53: Verifying Checksum
# e446a9769f53: Download complete
# 6aadf6f91a8d: Verifying Checksum
# 6aadf6f91a8d: Download complete
# 66d0708eeaf3: Verifying Checksum
# 66d0708eeaf3: Download complete
# 5952336ab5bb: Verifying Checksum
# 5952336ab5bb: Download complete
# 5b8a51d6bfdb: Verifying Checksum
# 5b8a51d6bfdb: Download complete
# 4493432064f7: Verifying Checksum
# 4493432064f7: Download complete
# 1e776d6ab67d: Verifying Checksum
# 1e776d6ab67d: Download complete
# 423bbe9704b1: Download complete
# fd9b2161165a: Verifying Checksum
# fd9b2161165a: Download complete
# 30b4effda4fd: Verifying Checksum
# 30b4effda4fd: Download complete
# 0a28138dee63: Verifying Checksum
# 0a28138dee63: Download complete
# 052e61da4995: Verifying Checksum
# 052e61da4995: Download complete
# be4f3343ecd3: Pull complete
# 30b4effda4fd: Pull complete
# b398e882f414: Pull complete
# f2e1f2321196: Pull complete
# 1e87b0a17e1a: Pull complete
# e446a9769f53: Pull complete
# 4493432064f7: Pull complete
# 6aadf6f91a8d: Pull complete
# 66d0708eeaf3: Pull complete
# 5952336ab5bb: Pull complete
# 5b8a51d6bfdb: Pull complete
# 1e776d6ab67d: Pull complete
# 423bbe9704b1: Pull complete
# fd9b2161165a: Pull complete
# 052e61da4995: Pull complete
# 0a28138dee63: Pull complete
# Digest: sha256:4932fc44edac0025d0c189c51532920fe8f118fafc82af6c1b8394c5e6c18927
# Status: Downloaded newer image for azureprojcrimi6hhqi4cj62.azurecr.io/azureml/azureml_bb7505235b95568dd47cb4e64da6eeda:latest
# b552ec16b69e204c4fbc482a9a7138be21d1811b43cbf8ba72b7eab8a12cbe47
#
# Streaming azureml-logs/65_job_prep-tvmps_11a6bc01d07234d5979ed836b7cc1d1394bea0d5b6cb70800269254b5828b3d0_d.txt
# ===============================================================================================================
#
# bash: /azureml-envs/azureml_92ac115cb67a69781c05c4b3d7de31a4/lib/libtinfo.so.5: no version information available (required by bash)
# Starting job preparation. Current time:2020-03-08T20:26:49.243883
# Extracting the control code.
# Creating directory: azureml-logs/
# Retrieving project from snapshot: d84c46c0-68dc-48c5-b2ac-94d18f670b1e
# Starting the daemon thread to refresh tokens in background for process with pid = 78
#
# Streaming azureml-logs/70_driver_log.txt
# ========================================
#
# bash: /azureml-envs/azureml_92ac115cb67a69781c05c4b3d7de31a4/lib/libtinfo.so.5: no version information available (required by bash)
# bash: /azureml-envs/azureml_92ac115cb67a69781c05c4b3d7de31a4/lib/libtinfo.so.5: no version information available (required by bash)
# Starting the daemon thread to refresh tokens in background for process with pid = 128
# Entering Run History Context Manager.
# Preparing to call script [ train.py ] with arguments: []
# After variable expansion, calling script [ train.py ] with arguments: []
#
# PyTorch version 1.3.1
# fastai version: 1.0.60
# CUDA supported: True
# CUDNN enabled: True
# extracting files...
# finished extracting
# /azureml-envs/azureml_92ac115cb67a69781c05c4b3d7de31a4/lib/python3.6/site-packages/fastai/vision/learner.py:106: UserWarning: `create_cnn` is deprecated and is now named `cnn_learner`.
#   warn("`create_cnn` is deprecated and is now named `cnn_learner`.")
# Downloading: "https://download.pytorch.org/models/resnet50-19c8e357.pth" to /root/.cache/torch/checkpoints/resnet50-19c8e357.pth
#
#   0%|          | 0.00/97.8M [00:00<?, ?B/s]
#   6%|▌         | 6.00M/97.8M [00:00<00:01, 61.3MB/s]
#  12%|█▏        | 11.6M/97.8M [00:00<00:01, 60.4MB/s]
#  17%|█▋        | 16.3M/97.8M [00:00<00:01, 56.3MB/s]
#  25%|██▍       | 24.1M/97.8M [00:00<00:01, 61.9MB/s]
#  31%|███       | 30.1M/97.8M [00:00<00:01, 60.5MB/s]
#  39%|███▉      | 38.4M/97.8M [00:00<00:00, 66.6MB/s]
#  48%|████▊     | 46.6M/97.8M [00:00<00:00, 71.4MB/s]
#  56%|█████▌    | 54.8M/97.8M [00:00<00:00, 69.1MB/s]
#  63%|██████▎   | 61.3M/97.8M [00:00<00:00, 64.8MB/s]
#  71%|███████   | 69.5M/97.8M [00:01<00:00, 69.9MB/s]
#  78%|███████▊  | 76.3M/97.8M [00:01<00:00, 69.3MB/s]
#  85%|████████▍ | 82.9M/97.8M [00:01<00:00, 67.8MB/s]
#  92%|█████████▏| 89.6M/97.8M [00:01<00:00, 68.5MB/s]
#  99%|█████████▊| 96.5M/97.8M [00:01<00:00, 69.1MB/s]
# 100%|██████████| 97.8M/97.8M [00:01<00:00, 66.5MB/s]
# █
# epoch     train_loss  valid_loss  accuracy  time
# █
# █
# 0         1.168308    0.714910    0.750000  00:24
# █
# epoch     train_loss  valid_loss  accuracy  time
# █
# █
# 0         0.511740    0.206134    0.964286  00:21
# █
# █
# █
# █
# █
# █
# █
# █
# █
# █
#
# The experiment completed successfully. Finalizing run...
# Cleaning up all outstanding Run operations, waiting 300.0 seconds
# 2 items cleaning up...
# Cleanup took 0.0015254020690917969 seconds
# Starting the daemon thread to refresh tokens in background for process with pid = 128
#
# Streaming azureml-logs/75_job_post-tvmps_11a6bc01d07234d5979ed836b7cc1d1394bea0d5b6cb70800269254b5828b3d0_d.txt
# ===============================================================================================================
#
# bash: /azureml-envs/azureml_92ac115cb67a69781c05c4b3d7de31a4/lib/libtinfo.so.5: no version information available (required by bash)
# Starting job release. Current time:2020-03-08T20:29:43.542112
# Logging experiment finalizing status in history service.
# Starting the daemon thread to refresh tokens in background for process with pid = 407
# Job release is complete. Current time:2020-03-08T20:29:46.214995
#
# Execution Summary
# =================
# RunId: cars-classifier_1583698130_be5c8985
# Web View: https://ml.azure.com/experiments/cars-classifier/runs/cars-classifier_1583698130_be5c8985?wsid=/subscriptions/d74ca76c-0758-4302-8894-12939776ca14/resourcegroups/fastai-practise/workspaces/Azure_projects
# {'runId': 'cars-classifier_1583698130_be5c8985',
#  'target': 'gpucluster',
#  'status': 'Completed',
#  'startTimeUtc': '2020-03-08T20:24:32.535442Z',
#  'endTimeUtc': '2020-03-08T20:30:05.751168Z',
#  'properties': {'_azureml.ComputeTargetType': 'amlcompute',
#   'ContentSnapshotId': '746abb6a-1cfd-4543-85ba-2d45d5735a4b',
#   'AzureML.DerivedImageName': 'azureml/azureml_bb7505235b95568dd47cb4e64da6eeda',
#   'ProcessInfoFile': 'azureml-logs/process_info.json',
#   'ProcessStatusFile': 'azureml-logs/process_status.json'},
#  'inputDatasets': [],
#  'runDefinition': {'script': 'train.py',
#   'useAbsolutePath': False,
#   'arguments': [],
#   'sourceDirectoryDataStore': None,
#   'framework': 'Python',
#   'communicator': 'None',
#   'target': 'gpucluster',
#   'dataReferences': {},
#   'data': {},
#   'jobName': None,
#   'maxRunDurationSeconds': None,
#   'nodeCount': 1,
#   'environment': {'name': 'Experiment cars-classifier Environment',
#    'version': 'Autosave_2020-03-08T20:08:52Z_ab7d0252',
#    'python': {'interpreterPath': 'python',
#     'userManagedDependencies': False,
#     'condaDependencies': {'channels': ['conda-forge'],
#      'dependencies': ['python=3.6.2',
#       {'pip': ['fastai==1.0.60',
#         'pillow==5.4.1',
#         'azureml-defaults',
#         'torch==1.3.1',
#         'torchvision==0.4.1',
#         'horovod==0.18.1',
#         'tensorboard==1.14.0',
#         'future==0.17.1']}],
#      'name': 'azureml_92ac115cb67a69781c05c4b3d7de31a4'},
#     'baseCondaEnvironment': None},
#    'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE',
#     'NCCL_TREE_THRESHOLD': '0'},
#    'docker': {'baseImage': 'mcr.microsoft.com/azureml/base-gpu:openmpi3.1.2-cuda10.1-cudnn7-ubuntu18.04',
#     'baseDockerfile': None,
#     'baseImageRegistry': {'address': None, 'username': None, 'password': None},
#     'enabled': True,
#     'arguments': []},
#    'spark': {'repositories': [], 'packages': [], 'precachePackages': False},
#    'inferencingStackVersion': None},
#   'history': {'outputCollection': True,
#    'directoriesToWatch': ['logs'],
#    'snapshotProject': True},
#   'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment',
#     'spark.yarn.maxAppAttempts': '1'}},
#   'amlCompute': {'name': None,
#    'vmSize': None,
#    'retainCluster': False,
#    'clusterMaxNodeCount': 1},
#   'tensorflow': {'workerCount': 1, 'parameterServerCount': 1},
#   'mpi': {'processCountPerNode': 1},
#   'hdi': {'yarnDeployMode': 'Cluster'},
#   'containerInstance': {'region': None, 'cpuCores': 2, 'memoryGb': 3.5},
#   'exposedPorts': None,
#   'docker': {'useDocker': True,
#    'sharedVolumes': True,
#    'shmSize': '2g',
#    'arguments': []}},
#  'logFiles': {'azureml-logs/20_image_build_log.txt': 'https://azureprojsaimi6hhqi4cj62.blob.core.windows.net/azureml/ExperimentRun/dcid.cars-classifier_1583698130_be5c8985/azureml-logs/20_image_build_log.txt?sv=2019-02-02&sr=b&sig=AUhJiD%2BA45yYnq3xCpk%2BclC0iBGtrGIIqKRXGln2moE%3D&st=2020-03-08T20%3A20%3A06Z&se=2020-03-09T04%3A30%3A06Z&sp=r',
#   'azureml-logs/55_azureml-execution-tvmps_11a6bc01d07234d5979ed836b7cc1d1394bea0d5b6cb70800269254b5828b3d0_d.txt': 'https://azureprojsaimi6hhqi4cj62.blob.core.windows.net/azureml/ExperimentRun/dcid.cars-classifier_1583698130_be5c8985/azureml-logs/55_azureml-execution-tvmps_11a6bc01d07234d5979ed836b7cc1d1394bea0d5b6cb70800269254b5828b3d0_d.txt?sv=2019-02-02&sr=b&sig=T%2BQALy5XOmGOsAfu25YlyiyFdVu3YrOtnO%2FEAiuqYbI%3D&st=2020-03-08T20%3A20%3A06Z&se=2020-03-09T04%3A30%3A06Z&sp=r',
#   'azureml-logs/65_job_prep-tvmps_11a6bc01d07234d5979ed836b7cc1d1394bea0d5b6cb70800269254b5828b3d0_d.txt': 'https://azureprojsaimi6hhqi4cj62.blob.core.windows.net/azureml/ExperimentRun/dcid.cars-classifier_1583698130_be5c8985/azureml-logs/65_job_prep-tvmps_11a6bc01d07234d5979ed836b7cc1d1394bea0d5b6cb70800269254b5828b3d0_d.txt?sv=2019-02-02&sr=b&sig=FsbgHmdwlP9hQU7htXiCZdvA0A95BhXp0r%2Becu4QXSY%3D&st=2020-03-08T20%3A20%3A06Z&se=2020-03-09T04%3A30%3A06Z&sp=r',
#   'azureml-logs/70_driver_log.txt': 'https://azureprojsaimi6hhqi4cj62.blob.core.windows.net/azureml/ExperimentRun/dcid.cars-classifier_1583698130_be5c8985/azureml-logs/70_driver_log.txt?sv=2019-02-02&sr=b&sig=BuwYQwE6InjywhITaBFpOFm9%2B72HBEROThyYwd9XCfY%3D&st=2020-03-08T20%3A20%3A06Z&se=2020-03-09T04%3A30%3A06Z&sp=r',
#   'azureml-logs/75_job_post-tvmps_11a6bc01d07234d5979ed836b7cc1d1394bea0d5b6cb70800269254b5828b3d0_d.txt': 'https://azureprojsaimi6hhqi4cj62.blob.core.windows.net/azureml/ExperimentRun/dcid.cars-classifier_1583698130_be5c8985/azureml-logs/75_job_post-tvmps_11a6bc01d07234d5979ed836b7cc1d1394bea0d5b6cb70800269254b5828b3d0_d.txt?sv=2019-02-02&sr=b&sig=ANJioJ5GvMnE%2F3PfGqhrgxxK1KsM%2BCOEI6H3ZWyyHl0%3D&st=2020-03-08T20%3A20%3A06Z&se=2020-03-09T04%3A30%3A06Z&sp=r',
#   'azureml-logs/process_info.json': 'https://azureprojsaimi6hhqi4cj62.blob.core.windows.net/azureml/ExperimentRun/dcid.cars-classifier_1583698130_be5c8985/azureml-logs/process_info.json?sv=2019-02-02&sr=b&sig=%2BVHiqwyyphHvmB0bEpZiIBS8If9JRnI8UmmhTODfjyA%3D&st=2020-03-08T20%3A20%3A07Z&se=2020-03-09T04%3A30%3A07Z&sp=r',
#   'azureml-logs/process_status.json': 'https://azureprojsaimi6hhqi4cj62.blob.core.windows.net/azureml/ExperimentRun/dcid.cars-classifier_1583698130_be5c8985/azureml-logs/process_status.json?sv=2019-02-02&sr=b&sig=Eh9FK1Oor9blx8KwVDN5Oyio%2FqYp%2BpA8Sad4pj12k38%3D&st=2020-03-08T20%3A20%3A07Z&se=2020-03-09T04%3A30%3A07Z&sp=r',
#   'logs/azureml/128_azureml.log': 'https://azureprojsaimi6hhqi4cj62.blob.core.windows.net/azureml/ExperimentRun/dcid.cars-classifier_1583698130_be5c8985/logs/azureml/128_azureml.log?sv=2019-02-02&sr=b&sig=b%2BVa94xByu%2B0%2BmstXami9AWQC8g%2B0g1KfKcZsctT%2BxA%3D&st=2020-03-08T20%3A20%3A06Z&se=2020-03-09T04%3A30%3A06Z&sp=r',
#   'logs/azureml/job_prep_azureml.log': 'https://azureprojsaimi6hhqi4cj62.blob.core.windows.net/azureml/ExperimentRun/dcid.cars-classifier_1583698130_be5c8985/logs/azureml/job_prep_azureml.log?sv=2019-02-02&sr=b&sig=0vnxjCJMBr86OxKlqUWOWYJz10qm2XdwUPgEhHl8WDU%3D&st=2020-03-08T20%3A20%3A06Z&se=2020-03-09T04%3A30%3A06Z&sp=r',
#   'logs/azureml/job_release_azureml.log': 'https://azureprojsaimi6hhqi4cj62.blob.core.windows.net/azureml/ExperimentRun/dcid.cars-classifier_1583698130_be5c8985/logs/azureml/job_release_azureml.log?sv=2019-02-02&sr=b&sig=cKItzI4K8dhZg8RbKj5J0ru369seTQgMD2%2FrCJMuF84%3D&st=2020-03-08T20%3A20%3A06Z&se=2020-03-09T04%3A30%3A06Z&sp=r'}}

# %%
model = run.register_model(model_name='cars-dnn', model_path='outputs/')

# %%
os.makedirs('./model', exist_ok=True)

for f in run.get_file_names():
    if f.startswith('outputs/model'):
        output_file_path = os.path.join('./model', f.split('/')[-1])
        print("Downloading from {} to {} ....".format(f, output_file_path))
        run.download_file(name=f,output_file_path=output_file_path)

# %%
import torch
from fastai import *
from fastai.vision import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-12-1e488d9063f5> in <module>
# ----> 1 import torch
#       2 from fastai import *
#       3 from fastai.vision import *
#
# ModuleNotFoundError: No module named 'torch'

# %%
learn = load_learner(path)

# %%
# !wget -O test.jpg 'https://cars.mclaren.com/content/dam/mclaren-automotive/ownership/Extended%20Warranty/Extended%20Warranty%20and%20Extended%20Service%20Contracts/1920x1080/_G3A8568_Hero.jpg'

# %%
img = open_image(os.path.join(os.getcwd(),"test.jpg"))
pred_class,pred_idx,outputs = learn_inference.predict(img)

# %%
pred_class
